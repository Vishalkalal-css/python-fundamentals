# %% [markdown]
# #1. python output

# %%
print("hellow world")
# Out:
# hellow world

# %%
print('salman khan')
# Out:
# salman khan

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('hello',1,4.5,True)
# Out:
# hello 1 4.5 True

# %%
print('hellow',end='-')
print('world')
# Out:
# hellow-world

# %% [markdown]
# #2. Data Types

# %%
#integer
print(8)
# 1*10^308
print(1e308)
# Out:
# 8
# 1e+308

# %%
#float/decimal
print(8.55)
print(1.7e308)
# Out:
# 8.55
# 1.7e+308

# %%
#booliean
print(True)
print(False)
# Out:
# True
# False

# %%
# text/sting
print('hello world')
# Out:
# hello world

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#list -> c-> Array
print([1,2,3,4,5,5])
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({'name':'nitish', 'gender': 'male','weight': 70})
# Out:
# {'name': 'nitish', 'gender': 'male', 'weight': 70}

# %%
#type
type(3)
# Out:
# int

# %% [markdown]
# #3. Veriables

# %%
#static Vs Dynamic Typing
# static vs dynamic binding
# stylish decleration techniques

# %%
name = 'vishal'
print(name)


a = 5
b = 8
print(a+b)
# Out:
# vishal
# 13

# %%
#dynamic typing
a = 5
#static typing
int a = 5

# %%
#dynamic binding
a = 5
print(a)
a = 'nitesh'
print(a)
# Out:
# 5
# nitesh

# %%
#stylish techniues
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c= 10
print(a,b,c)
# Out:
# 10 10 10

# %% [markdown]
# #4. Keywords & Identifiers

# %%
#keywords

# %%
# Identifiers
# you can't start with a digit
# you can use special chars -->>  _
# identifiers can't be keywords

# %% [markdown]
# # 5. User Input

# %%
fnum = input('enter first number : ')
snum = input('enter second number : ')
result = int(fnum) + int(snum)
print(result)
# Out:
# enter first number : 25
# enter second number : 45
# 70

# %% [markdown]
# # 6. Type Conversion

# %%
#implicit vs explicit
print(5+5.6)
print(type(5),type(5.6))
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
#explicit
# str --> int
#int(4+9j) not possible for complex number

#int --> str
str(5)

#float
float(4)
# Out:
# 4.0

# %% [markdown]
# #7.Literals

# %%
a = 0b1010 #binary literals
b = 100 #Decimal literals
c = 0o310 #octal literals
d = 0x12c #hexadecimal literals

#float literals
float_1 = 10.5
float_2 = 1.5e2
float_3 = 1.5e-3

#complex literas
X = 3.14j

# %%
from re import MULTILINE
string = 'This is python'
strings = "This is phthon"
char = "c"
MULTILINE_str = """This is multiline strings with more than one line code."""
unicode = u"\U0001f607\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(MULTILINE_str)
print(unicode)
print(raw_str)
# Out:
# This is python
# This is phthon
# c
# This is multiline strings with more than one line code.
# 😇😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
a = None
print(a)
# Out:
# None
